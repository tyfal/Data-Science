# %%
from html2text import html2text
import requests

r = requests.get('http://moviebodycounts.com/Braveheart.htm')

print(html2text(r.text))
# Out:
# ![](clr_spcr.gif)
# ---
# | [![](header1.jpg)](Hard_Boiled.htm)
# | [![](header2.jpg)](equilibrium.htm)
# | [![](header3.jpg)](saving_private_ryan.htm)
# | [![](header4.jpg)](http://www.moviebodycounts.com/)
# | ![](clr_spcr.gif)
# ---|---|---|---|---
# | [![](Nav-Button1.jpg)](http://www.moviebodycounts.com/)
# ---
# [![](Nav-Button2.jpg)](movies.htm)
# [![](Nav-Button3.jpg)](actors.htm)
# [![](Nav-Button4.jpg)](directors.htm)
# [![](Nav-Button5.jpg)](charts.htm)
# [![](Nav-Button6.jpg)](faq.htm)
# [![](Nav-Button7.jpg)](http://moviebodycounts.proboards80.com/index.cgi)
# [![](Nav-Button8.jpg)](contact.htm)
# ![](Nav-bottom.jpg)
# ![](clr_spcr.gif)
# | ![](clr_spcr.gif) | ![](boarder-rt.jpg)
# ---|---
# ![](clr_spcr.gif)
#
#
#
# | ![](clr_spcr.gif)
# ---
# |
# | ![](clr_spcr.gif) | ![](clr_spcr.gif)
# ---|---|---
#
# |
# | ![](graphic-Braveheart.jpg)
# |
#
# Braveheart
#
# ([1995](charts-year-1990.htm))
#
# ---|---
#
#
#
#
# |
# |
#
#
# |
#
#
# ...
