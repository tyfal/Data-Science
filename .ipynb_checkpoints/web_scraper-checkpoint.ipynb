# %%
from html2text import html2text
import requests

r = requests.get('https://www.youtube.com/watch?v=qfGthiqwaZo')

print(html2text(r.text))
# Out:
# Skip navigation
#
# [ ](/ "YouTube Home" )
#
# [Upload](//www.youtube.com/upload)
#
# Sign in
#
# Search
#
# Loading...
#
# Close
#
# Yeah, keep it Undo Close
#
# ![](//s.ytimg.com/yts/img/pixel-vfl3z5WfW.gif)
#
# #  This video is unavailable.
#
# ### Watch Queue
#
# ### Queue
#
# Watch QueueQueue
#
#   * Remove all
#   * Disconnect
#
# Loading...
#
# Watch Queue
#
# Queue
#
# __count__/__total__
#
# [Find out
# why](https://www.google.com/get/videoqualityreport/?v=qfGthiqwaZo)Close
#
# #  Quick and dirty web scraping with Python
#
# [ ![Randy Olson](https://s.ytimg.com/yts/img/pixel-vfl3z5WfW.gif)
# ](/user/Rhiever)
#
# [Randy Olson](/channel/UCvEj2pLBlh_LpfJx7LxXh9A)
#
# SubscribeSubscribedUnsubscribe155155
#
# Loading...
#
# Loading...
#
# Working...
#
# Add to
#
# ### Want to watch this again later?
#
# Sign in to add this video to a playlist.
#
# [Sign
# ...
